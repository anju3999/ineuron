# %% [markdown]
# # Task 1:

# %% [markdown]
# 1.1 Write a Python Program to implement your own myreduce() function which works exactly like
# Python's built-in function reduce()

# %%
from functools import reduce

# %%
def myreduce(fun,l,init= None):
    iterable=iter(l)
    if init == None:
        result = next(iterable)
    else:
        result = init
    for i in iterable:
        result=fun(result,i)
    return result

# %%
l=[2,3,4,5,6]
print(myreduce(lambda x,y:x+y,l))
print(myreduce(lambda x,y:x+y,l,20))
# Out:
# 20
# 40

# %% [markdown]
# ![1.1.PNG](attachment:1.1.PNG)

# %% [markdown]
# 1.2 Write a Python program to implement your own myfilter() function which works exactly like
# Python's built-in function filter()

# %%
def myfilter(fun,l):
    iterable=iter(l)
    for i in iterable:
        if fun(i):
            yield i

# %%
l=[2,6,8,3,5,7,9,10]
for i in myfilter(lambda x:x%2==0,l):
    print(i)
# Out:
# 2
# 6
# 8
# 10

# %% [markdown]
# ![1.2.PNG](attachment:1.2.PNG)

# %% [markdown]
# 2. Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists
#
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
#
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
#
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
#
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
#
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
#
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
string="acadgild"
lc1=[i.upper() for i in string]
string2="xyz"
lc2=[i*(j+1) for i in string2 for j in range(4)]
lc3=[(i+1)*j for i in range(4) for j in string2]
lc4=[[i+j+2]for i in range(3) for j in range(3)]
lc5=[[i+j+2 for i in range(4)]for j in range(4)]
lc6=[(j+1,i+1) for i in range(3) for j in range(3)]
print(lc1)
print(lc2)
print(lc3)
print(lc4)
print(lc5)
print(lc6)
# Out:
# ['A', 'C', 'A', 'D', 'G', 'I', 'L', 'D']
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# 3. Implement a function longestWord() that takes a list of words and returns the longest one.

# %%
def longestWord(l):
    length=[len(i) for i in l]
    initial=length[0]
    for i in range(1,len(length)):
        if length[i]>initial:
            initial=length[i]
    return l[length.index(initial)]

# %%
l=["shxwxf","uhderge3ui3iyd3d","gry4rf3","jejhd","uy3dt3fd"]
longestWord(l)
# Out:
# 'uhderge3ui3iyd3d'

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# # Task2:

# %% [markdown]
# 1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
#
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
#
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
class shape:
    def getSides(self):
        self.a = int(input('Enter length of 1st side: '))
        self.b = int(input('Enter length of 2nd side: '))
        self.c = int(input('Enter length of 3rd side: '))

class triangle(shape):
    def getArea(self):
        self.getSides()
        s = (self.a + self.b + self.c) / 2
        self.area = (s*(s-self.a)*(s-self.b)*(s-self.c)) ** 0.5
        print(f'area = {self.area}')
        
t1 = triangle()
t1.getArea()
# Out:
# Enter length of 1st side: 25
# Enter length of 2nd side: 45
# Enter length of 3rd side: 35
# area = 435.30700373414624

# %% [markdown]
# ![1.1%282%29.PNG](attachment:1.1%282%29.PNG)

# %% [markdown]
# 1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list
# of words that are longer than n.

# %%
def filter_long_words(l,n):
    return [i for i in l if len(i) > n]
s=["abc","kiwi","apple","banana"]
filter_long_words(s,4)
# Out:
# ['apple', 'banana']

# %% [markdown]
# ![filter.PNG](attachment:filter.PNG)

# %% [markdown]
# 2.1 Write a Python program using function concept that maps list of words into a list of integers representing the lengths of the corresponding words.

# %%
def fun(l):
    return [len(i) for i in l]
l=["apple","banana","kiwi","strawberry"]
print(fun(l))
# Out:
# [5, 6, 4, 10]

# %% [markdown]
# ![2.1.PNG](attachment:2.1.PNG)

# %% [markdown]
# 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise.

# %%
def isvowel(c):
    c.lower()
    if c in ['a', 'e', 'i', 'o', 'u']:
        return True
    else:
        return False
    
print(isvowel('a'))
print(isvowel('y'))
# Out:
# True
# False

# %% [markdown]
# ![2.2.PNG](attachment:2.2.PNG)
